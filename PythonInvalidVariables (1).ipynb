# %% [markdown]
# # Python Invalid Variables
#
# **Rules for creating variables in Python:**
#
# 1. A variable name must start with a letter or the underscore character.
# 2. A variable name cannot start with a number.
# 3. A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ ).
# 4. Variable names are case-sensitive (name, Name and NAME are three different variables).
# 5. The reserved words(keywords) cannot be used naming the variable.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
name = "Python Programming"
Name = "Java Programming"
NAME = "C++ Programming"
nAme = "PL/SQL Programming"
naMe = "Pascal Programming"
print(name)
print(Name)
print(NAME)
print(nAme)
print(naMe)
# Out:
# Python Programming
# Java Programming
# C++ Programming
# PL/SQL Programming
# Pascal Programming

# %%
Python = "Language"
print(Python)
# Out:
# Language

# %%
num = 12345678
print(num)

num = 3.14
print(num)

num = 9+3j
print(num)
# Out:
# 12345678
# 3.14
# (9+3j)

# %%
var_bool = True
print(var_bool)

var_bool = False
print(var_bool)
# Out:
# True
# False

# %%
1Num = 123456789
# SyntaxError: invalid syntax
# invalid variable

# %%
2Num = 123456789
# SyntaxError: invalid syntax
# invalid variable

# %%
# !Num = 123456789
# /bin/bash: Num: command not found
# Exclaimation try to run the command
# like, !pip install library
# invalid variable
# Out:
# /bin/bash: Num: command not found

# %%
@Num = 123456789
# SyntaxError: invalid syntax
# invalid variable
# Out:
#   File "<ipython-input-10-e336f7a3e304>", line 1
#     @Num = 123456789
#          ^
# SyntaxError: invalid syntax

# %%
#Num = 123456789
# invalid variable

# %%
$Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-12-640559e961f2>", line 1
#     $Num = 123456789
#     ^
# SyntaxError: invalid syntax

# %%
# %Num = 123456789
# UsageError: Line magic function `%Num` not found.
# Invalid variable
# Out:
# UsageError: Line magic function `%Num` not found.

# %%
^Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-14-8e15801269d6>", line 1
#     ^Num = 123456789
#     ^
# SyntaxError: invalid syntax

# %%
&Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-15-da124e7dc402>", line 1
#     &Num = 123456789
#     ^
# SyntaxError: invalid syntax

# %%
*Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# SyntaxError: starred assignment target must be in a list or tuple
# Out:
#   File "<ipython-input-16-56c666bd3d40>", line 1
#     *Num = 123456789
#                     ^
# SyntaxError: starred assignment target must be in a list or tuple

# %%
(Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable
 
[Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable
 
{Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable

# %%
)Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable

}Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable

]Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable

# %%
-Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# SyntaxError: can't assign to operator

# %%
+Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# SyntaxError: can't assign to operator

# %%
=Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable

# %%
>Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable

# %%
<Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable

# %%
# ?Num = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Object `Num` not found.
# Out:
# Object `Num` not found.

# %%
break = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-4-7515fd488d87>", line 1
#     break = 123456789
#           ^
# SyntaxError: invalid syntax

# %%
continue = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-5-cfba4e6a8494>", line 1
#     continue = 123456789
#              ^
# SyntaxError: invalid syntax

# %%
except = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-6-7bb557fc5ec9>", line 1
#     except = 123456789
#          ^
# SyntaxError: invalid syntax

# %%
False = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-13-25a351861427>", line 1
#     False = 123456789
#                      ^
# SyntaxError: can't assign to keyword

# %%
finally = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-12-70eac38f25eb>", line 1
#     finally = 123456789
#           ^
# SyntaxError: invalid syntax

# %%
for = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-11-a1917e6562b2>", line 1
#     for = 123456789
#         ^
# SyntaxError: invalid syntax

# %%
lambda = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-9-1ad0dd098299>", line 1
#     lambda = 123456789
#            ^
# SyntaxError: invalid syntax

# %%
None = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-8-15ff30a063e6>", line 1
#     None = 123456789
#                     ^
# SyntaxError: can't assign to keyword

# %%
True = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-7-bf36ebd8a544>", line 1
#     True = 123456789
#                     ^
# SyntaxError: can't assign to keyword

# %%
while = 123456789
# SyntaxError: invalid syntax
# Invalid variable
# Out:
#   File "<ipython-input-6-00aacd5e3a3d>", line 1
#     while = 123456789
#           ^
# SyntaxError: invalid syntax

# %%
_Num = 123456789
print(_Num)
# Out:
# 123456789

# %%
__Num = 123456789
print(_Num)
# Out:
# 123456789
